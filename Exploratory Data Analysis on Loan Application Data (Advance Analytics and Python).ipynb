# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sb

# %% [markdown]
# ## IMPORTING THE CSV FILES OF previous_application and application_data

# %%
df1 = pd.read_csv('previous_application.csv')

# %%
df2 = pd.read_csv('application_data (1).csv')

# %%
df2.shape
# Out:
# (307511, 122)

# %% [markdown]
# ### Finding the shape of application_data

# %%
emptycol=df2.isnull().sum()
emptycol=emptycol[emptycol.values>(0.6*len(emptycol))]
len(emptycol)
# Out:
# 64

# %%
null_count = df2.isnull().values.sum()
null_count
# Out:
# 9152465

# %%
null_count = df2.isnull().sum()
null_percentage = round((df2.isnull().sum() / df2.shape[0]) * 100, 2)
null_percentage_sorted = null_percentage.sort_values(ascending=False)
null_percentage_sorted
# Out:
# COMMONAREA_MEDI             69.87
# COMMONAREA_AVG              69.87
# COMMONAREA_MODE             69.87
# NONLIVINGAPARTMENTS_MODE    69.43
# NONLIVINGAPARTMENTS_AVG     69.43
#                             ...
# NAME_FAMILY_STATUS           0.00
# NAME_EDUCATION_TYPE          0.00
# NAME_INCOME_TYPE             0.00
# AMT_ANNUITY                  0.00
# SK_ID_CURR                   0.00
# Length: 122, dtype: float64

# %% [markdown]
# # Finding out the columns with their corresponding null values percentage in descending order, to find out which columns having highest null values

# %%
null_df = pd.DataFrame({'column_name' : df2.columns,'null_count' : null_count,'null_percentage': null_percentage})
null_df.sort_values(by = 'null_percentage', ascending = False)
# Out:
#                                        column_name  null_count  \
# COMMONAREA_MEDI                    COMMONAREA_MEDI      214865
# COMMONAREA_AVG                      COMMONAREA_AVG      214865
# COMMONAREA_MODE                    COMMONAREA_MODE      214865
# NONLIVINGAPARTMENTS_MODE  NONLIVINGAPARTMENTS_MODE      213514
# NONLIVINGAPARTMENTS_AVG    NONLIVINGAPARTMENTS_AVG      213514
# ...                                            ...         ...
# NAME_FAMILY_STATUS              NAME_FAMILY_STATUS           0
# NAME_EDUCATION_TYPE            NAME_EDUCATION_TYPE           0
# NAME_INCOME_TYPE                  NAME_INCOME_TYPE           0
# AMT_ANNUITY                            AMT_ANNUITY          12
# SK_ID_CURR                              SK_ID_CURR           0
#
#                           null_percentage
# COMMONAREA_MEDI                     69.87
# COMMONAREA_AVG                      69.87
# COMMONAREA_MODE                     69.87
# ...

# %%
columns_to_be_deleted = null_df[null_df['null_percentage'] > 40]
columns_to_be_deleted
# Out:
#                                                column_name  null_count  \
# OWN_CAR_AGE                                    OWN_CAR_AGE      202929
# EXT_SOURCE_1                                  EXT_SOURCE_1      173378
# APARTMENTS_AVG                              APARTMENTS_AVG      156061
# BASEMENTAREA_AVG                          BASEMENTAREA_AVG      179943
# YEARS_BEGINEXPLUATATION_AVG    YEARS_BEGINEXPLUATATION_AVG      150007
# YEARS_BUILD_AVG                            YEARS_BUILD_AVG      204488
# COMMONAREA_AVG                              COMMONAREA_AVG      214865
# ELEVATORS_AVG                                ELEVATORS_AVG      163891
# ENTRANCES_AVG                                ENTRANCES_AVG      154828
# FLOORSMAX_AVG                                FLOORSMAX_AVG      153020
# FLOORSMIN_AVG                                FLOORSMIN_AVG      208642
# LANDAREA_AVG                                  LANDAREA_AVG      182590
# ...

# %% [markdown]
# # Deleting columns which are having  Null Values greater than 40%
# - From the above plot it can be observed that many columns have null values greater than 40%
# - As the null value percentage is increasing, it will become difficult to handle missing data
# - Hence we decide to drop the columns that are having null values more than 40%

# %%
filtered_dataframe = df2.drop(columns_to_be_deleted.index, axis = 1) #new df having columns null values < 40%

# %%
import plotly as plt

# %%
from matplotlib import pyplot as plt
import pylab
from pylab import plot,show
from pylab import legend,title,xlabel,ylabel

# %%
plt.figure(figsize=(150, 75), dpi=100)
columns_to_be_deleted.plot(kind="bar",x='column_name',y='null_percentage')
plt.title("Null values in columns")
plt.xlabel('Column Names')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# # Graph showing the Columns with their %Null Values on Y axis

# %%
filtered_dataframe.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE',
#        'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
#        'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_MOBIL',
#        'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
#        'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
#        'ORGANIZATION_TYPE', 'EXT_SOURCE_2', 'EXT_SOURCE_3',
# ...

# %%
filtered_dataframe1 = filtered_dataframe[['TARGET','NAME_CONTRACT_TYPE','CODE_GENDER','FLAG_OWN_CAR','FLAG_OWN_REALTY',
               'CNT_CHILDREN','AMT_INCOME_TOTAL','AMT_CREDIT','AMT_ANNUITY','AMT_GOODS_PRICE',
               'NAME_TYPE_SUITE','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS',
               'NAME_HOUSING_TYPE','REGION_POPULATION_RELATIVE','DAYS_BIRTH','DAYS_EMPLOYED',
               'OCCUPATION_TYPE','CNT_FAM_MEMBERS','REGION_RATING_CLIENT_W_CITY',
               'ORGANIZATION_TYPE','EXT_SOURCE_2','OBS_30_CNT_SOCIAL_CIRCLE','DEF_30_CNT_SOCIAL_CIRCLE',
               'OBS_60_CNT_SOCIAL_CIRCLE','DEF_60_CNT_SOCIAL_CIRCLE','FLAG_DOCUMENT_2','FLAG_DOCUMENT_3',
               'FLAG_DOCUMENT_20','FLAG_DOCUMENT_21','AMT_REQ_CREDIT_BUREAU_YEAR']]

# %% [markdown]
# # Selecting the necessarey columns according to own understanding and creating new dataframe

# %%
filtered_dataframe1.shape
# Out:
# (307511, 32)

# %%
len(filtered_dataframe1.columns[filtered_dataframe1.isnull().any()])
# Out:
# 11

# %%
null_count1 = filtered_dataframe1.isnull().sum()
null_percentage1 = round((filtered_dataframe1.isnull().sum() / filtered_dataframe1.shape[0]) * 100, 2)
null_percentage1_sorted1 = null_percentage1.sort_values(ascending=False)
null_percentage1_sorted1
# Out:
# OCCUPATION_TYPE                31.35
# AMT_REQ_CREDIT_BUREAU_YEAR     13.50
# NAME_TYPE_SUITE                 0.42
# DEF_60_CNT_SOCIAL_CIRCLE        0.33
# OBS_60_CNT_SOCIAL_CIRCLE        0.33
# OBS_30_CNT_SOCIAL_CIRCLE        0.33
# DEF_30_CNT_SOCIAL_CIRCLE        0.33
# EXT_SOURCE_2                    0.21
# AMT_GOODS_PRICE                 0.09
# FLAG_DOCUMENT_21                0.00
# FLAG_DOCUMENT_20                0.00
# FLAG_DOCUMENT_3                 0.00
# FLAG_DOCUMENT_2                 0.00
# DAYS_EMPLOYED                   0.00
# ORGANIZATION_TYPE               0.00
# REGION_RATING_CLIENT_W_CITY     0.00
# CNT_FAM_MEMBERS                 0.00
# TARGET                          0.00
# NAME_CONTRACT_TYPE              0.00
# REGION_POPULATION_RELATIVE      0.00
# NAME_HOUSING_TYPE               0.00
# NAME_FAMILY_STATUS              0.00
# NAME_EDUCATION_TYPE             0.00
# NAME_INCOME_TYPE                0.00
# AMT_ANNUITY                     0.00
# ...

# %%
filtered_dataframe1['AMT_REQ_CREDIT_BUREAU_YEAR'].fillna(method = 'ffill', inplace = True)
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\570662523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1['AMT_REQ_CREDIT_BUREAU_YEAR'].fillna(method = 'ffill', inplace = True)

# %%
filtered_dataframe1['OCCUPATION_TYPE'].fillna(value=  'Unknown', inplace = True)
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\949731371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1['OCCUPATION_TYPE'].fillna(value=  'Unknown', inplace = True)

# %%
null_count2 = filtered_dataframe1['OCCUPATION_TYPE'].isnull().sum()
null_count2
# Out:
# 0

# %% [markdown]
# # Checking %Null values in new dataframe and fill them with Techniqes by studying all the ascpects.

# %%
null_count1 = filtered_dataframe1.isnull().sum().sum()
null_count1
# Out:
# 6328

# %%
filtered_dataframe1['DAYS_BIRTH']= (round(abs(filtered_dataframe1['DAYS_BIRTH'])/365)).astype(int)
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\2286943024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1['DAYS_BIRTH']= (round(abs(filtered_dataframe1['DAYS_BIRTH'])/365)).astype(int)

# %%
filtered_dataframe1['DAYS_BIRTH'].head()
# Out:
# 0    26
# 1    46
# 2    52
# 3    52
# 4    55
# Name: DAYS_BIRTH, dtype: int32

# %%
filtered_dataframe1.rename(columns = {'DAYS_BIRTH':'AGE'}, inplace = True)
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\829655275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1.rename(columns = {'DAYS_BIRTH':'AGE'}, inplace = True)

# %%
filtered_dataframe1.columns
# Out:
# Index(['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'AGE', 'DAYS_EMPLOYED', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT_W_CITY', 'ORGANIZATION_TYPE',
#        'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE',
#        'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object')

# %%
filtered_dataframe1['DAYS_EMPLOYED'] = round((abs(filtered_dataframe1['DAYS_EMPLOYED'])/365),2)
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\1622476425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1['DAYS_EMPLOYED'] = round((abs(filtered_dataframe1['DAYS_EMPLOYED'])/365),2)

# %%
filtered_dataframe1['DAYS_EMPLOYED'].head()
# Out:
# 0    1.75
# 1    3.25
# 2    0.62
# 3    8.33
# 4    8.32
# Name: DAYS_EMPLOYED, dtype: float64

# %%
filtered_dataframe1.rename(columns = {'DAYS_EMPLOYED':'YEARS_OF_EXP'}, inplace = True)
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\110842424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1.rename(columns = {'DAYS_EMPLOYED':'YEARS_OF_EXP'}, inplace = True)

# %%
filtered_dataframe1['AGE'] = pd.cut(x=filtered_dataframe1['AGE'],
                      bins=[0,20,30,40,50,60,100],
                             labels=['0-20','21-30','31-40','41-50','51-60','61-100'])
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\338260216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1['AGE'] = pd.cut(x=filtered_dataframe1['AGE'],

# %% [markdown]
# # Creating beans to formulate the graph

# %%
import seaborn
seaborn.countplot(x='AGE',data=filtered_dataframe1,order=filtered_dataframe1['AGE'].value_counts().index)
# Out:
# <Axes: xlabel='AGE', ylabel='count'>

# %% [markdown]
# - It can be observed that people of age group 30-40 are the most who apply for loan
# - This is followed by age group 40-50

# %%
filtered_dataframe1['YEARS_OF_EXP']=pd.cut(
                             x=filtered_dataframe1['YEARS_OF_EXP'],
                             bins=[0,5,10,15,20,25,30,100],
                             labels=['0-5','6-10','11-15','16-20','21-25','26-30','31-100'])
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\2992926910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1['YEARS_OF_EXP']=pd.cut(

# %% [markdown]
# # Creating beans to formulate the graph

# %%
seaborn.countplot(x='YEARS_OF_EXP',data=filtered_dataframe1,order=filtered_dataframe1['YEARS_OF_EXP'].value_counts().index)
# Out:
# <Axes: xlabel='YEARS_OF_EXP', ylabel='count'>

# %% [markdown]
# Graph showing the freqency/count according to Yrars_of_exp, it can be observed that people will less experience i.e experience between 0 to 5 years are the one who apply for the loan in highest number

# %%
filtered_dataframe1['CODE_GENDER'].replace({'XNA':'F'},inplace=True)
# Out:
# C:\Users\vaibhau\AppData\Local\Temp\ipykernel_18972\3258479480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe1['CODE_GENDER'].replace({'XNA':'F'},inplace=True)

# %%
seaborn.barplot(x='CODE_GENDER', y='AMT_INCOME_TOTAL',data=filtered_dataframe1)
# Out:
# <Axes: xlabel='CODE_GENDER', ylabel='AMT_INCOME_TOTAL'>

# %% [markdown]
# # Comparing the Income according to Gender, male average earning is more than female

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10,2))
seaborn.boxplot(filtered_dataframe1['EXT_SOURCE_2'],orient='h')
plt.show()

# %% [markdown]
# # As observed from above plot, there are no outliers/extreamities.

# %%
plt.figure(figsize = (10,5))
seaborn.countplot(data = filtered_dataframe1, x = "NAME_TYPE_SUITE")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Graph showing the Name_Type_suite and its counts/frequency

# %%
seaborn.boxplot(filtered_dataframe1.DEF_30_CNT_SOCIAL_CIRCLE,orient='h')
# Out:
# <Axes: >

# %% [markdown]
# # above graph showing their are many outliers, in DEF_30_CNT_SOCIAL_CIRCLE, can consider this factor while giving loan

# %%
seaborn.boxplot(filtered_dataframe1.OBS_30_CNT_SOCIAL_CIRCLE,orient='h')
# Out:
# <Axes: >

# %% [markdown]
# # above graph showing their areoutliers, in OBS_30_CNT_SOCIAL_CIRCLE, can consider this factor while giving loan

# %%
seaborn.boxplot(filtered_dataframe1.OBS_60_CNT_SOCIAL_CIRCLE,orient='h')
# Out:
# <Axes: >

# %% [markdown]
# # above graph showing their areoutliers, in OBS_60_CNT_SOCIAL_CIRCLE, can consider this factor while giving loan

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Set the figure size to 10 inches (width) by 6 inches (height)
sns.barplot(x='NAME_TYPE_SUITE', y='AMT_INCOME_TOTAL', data=filtered_dataframe1)
plt.show()

# %% [markdown]
# # Above Graph showing the relation between Name_type_suite and their equiivalent Amt_income

# %%
plt.figure(figsize = (12,3))
sns.boxplot(filtered_dataframe1['AMT_INCOME_TOTAL'],orient='h')
plt.show()

# %% [markdown]
# # above graph showing the, AMT_INCOME_TOTAL and its outliers

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = filtered_dataframe1['TARGET'], data = filtered_dataframe1)
plt.title('Checking imbalance ratio of TARGET variable')
plt.show()

# %%
plt.figure(figsize = [20,8])
(filtered_dataframe1['TARGET'].value_counts(normalize=True)*100).plot.bar(title = "% Imbalance bwtween 0 and 1 ", color=['blue', 'green'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Above two graphs are showing that, majority of the people are paying their payments without any delay

# %% [markdown]
# # UNIIVARIATE

# %%
dftar0 = filtered_dataframe1[filtered_dataframe1['TARGET'] == 0]
dftar1 = filtered_dataframe1[filtered_dataframe1['TARGET'] == 1]

# %% [markdown]
# # created two dataframes classified by target 0 and target 1

# %%
plt.figure(figsize = (10,5))
seaborn.countplot(data = dftar1, x = "NAME_CONTRACT_TYPE")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10,5))
seaborn.countplot(data = dftar0, x = "NAME_CONTRACT_TYPE")
plt.xticks(rotation = 90)
plt.show()
#uni variate analysis

# %%
plt.figure(figsize=(10, 5))
counts = dftar1['NAME_CONTRACT_TYPE'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title("Distribution of NAME_CONTRACT_TYPE")
plt.show()

# %%
plt.figure(figsize=(10, 5))
counts = dftar0['NAME_CONTRACT_TYPE'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title("Distribution of NAME_CONTRACT_TYPE")
plt.show()

# %%
plt.figure(figsize = (10,5))
seaborn.countplot(data = dftar1, x = "CODE_GENDER")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # In above Graph, % of females who are from category 1 are more than Male from category 1 (% defaulter(females) are more)

# %%
plt.figure(figsize = (10,5))
seaborn.countplot(data = dftar0, x = "CODE_GENDER")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # In above Graph, % of females who are from category 0 are more than Male from category 0(applying loan)

# %%
plt.figure(figsize=(10, 5))
counts = dftar1['CODE_GENDER'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title("Distribution of CODE_GENDER")
plt.show()

# %%
plt.figure(figsize=(10, 5))
counts = dftar0['CODE_GENDER'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title("Distribution of CODE_GENDER")
plt.show()

# %%
plt.figure(figsize = (10,5))
seaborn.countplot(data = dftar1, x = "NAME_INCOME_TYPE")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # from above graph we can concude that working professionals are applying for loan process, from target cat 1

# %%
plt.figure(figsize = (10,5))
seaborn.countplot(data = dftar0, x = "NAME_INCOME_TYPE")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # from above graph we can concude that working professionals are applying for loan process, from target cat 0

# %%
corr_df1 = dftar1.select_dtypes(include=["int64","float64"]).corr()
corr_df0 = dftar0.select_dtypes(include=["int64","float64"]).corr()

# %%
cdf1 = corr_df1[corr_df1 <= 0.99].unstack().sort_values(ascending = False) #taking top 10 influencing factors
for i in range(0,20,2):
    print(cdf1[[i]])
# Out:
# AMT_CREDIT  AMT_GOODS_PRICE    0.983103
# dtype: float64
# CNT_CHILDREN  CNT_FAM_MEMBERS    0.885484
# dtype: float64
# DEF_60_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE    0.868994
# dtype: float64
# AMT_GOODS_PRICE  AMT_ANNUITY    0.752699
# dtype: float64
# AMT_ANNUITY  AMT_CREDIT    0.752195
# dtype: float64
# OBS_60_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE    0.337181
# dtype: float64
# DEF_30_CNT_SOCIAL_CIRCLE  OBS_30_CNT_SOCIAL_CIRCLE    0.333825
# dtype: float64
# DEF_60_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE    0.264159
# dtype: float64
# DEF_60_CNT_SOCIAL_CIRCLE  OBS_30_CNT_SOCIAL_CIRCLE    0.261009
# dtype: float64
# REGION_POPULATION_RELATIVE  EXT_SOURCE_2    0.169751
# dtype: float64

# %%
cdf0 = corr_df0[corr_df0 <= 0.99].unstack().sort_values(ascending = False)
for i in range(0,20,2):
    print(cdf0[[i]])
# Out:
# AMT_GOODS_PRICE  AMT_CREDIT    0.98725
# dtype: float64
# CNT_FAM_MEMBERS  CNT_CHILDREN    0.878571
# dtype: float64
# DEF_60_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE    0.859332
# dtype: float64
# AMT_ANNUITY  AMT_GOODS_PRICE    0.776686
# dtype: float64
# AMT_ANNUITY  AMT_CREDIT    0.771309
# dtype: float64
# AMT_INCOME_TOTAL  AMT_ANNUITY    0.418953
# dtype: float64
# AMT_GOODS_PRICE  AMT_INCOME_TOTAL    0.349462
# dtype: float64
# AMT_CREDIT  AMT_INCOME_TOTAL    0.342799
# dtype: float64
# DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE    0.331336
# dtype: float64
# DEF_30_CNT_SOCIAL_CIRCLE  OBS_30_CNT_SOCIAL_CIRCLE    0.329206
# dtype: float64

# %% [markdown]
# # above is the list top rated columns which are having highest co-relation betweeen them

# %% [markdown]
# # Bivariate

# %%
plt.figure(figsize=(16,12))
plt.xticks(rotation=45)
sns.boxplot(data =dftar0, x='NAME_EDUCATION_TYPE',y='AMT_CREDIT', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('Credit amount vs Education Status')
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.xticks(rotation=45)
sns.boxplot(data =dftar1, x='NAME_EDUCATION_TYPE',y='AMT_CREDIT', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('Credit amount vs Education Status')
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.xticks(rotation=45)
plt.yscale('log')
sns.boxplot(data =dftar0, x='NAME_EDUCATION_TYPE',y='AMT_INCOME_TOTAL', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('Income amount vs Education Status')
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.xticks(rotation=45)
plt.yscale('log')
sns.boxplot(data =dftar1, x='NAME_EDUCATION_TYPE',y='AMT_INCOME_TOTAL', hue ='NAME_FAMILY_STATUS',orient='v')
plt.title('Income amount vs Education Status')
plt.show()

# %% [markdown]
# # above Bivariate graphs showing the box plots for the entities wrt to amt_income_total, this can give clear about the highest incomed categories with their extreamities with their variation

# %%
df1 = pd.read_csv('previous_application.csv')
df1.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %%
null_count_df1 = df1.isnull().values.sum()
null_count_df1
# Out:
# 11109336

# %%
null_count_df1 = df1.isnull().sum()
null_percentage_df1 = round((df1.isnull().sum() / df1.shape[0]) * 100, 2)
null_percentage_sorted_df1 = null_percentage_df1.sort_values(ascending=False)
null_percentage_sorted_df1
# Out:
# RATE_INTEREST_PRIVILEGED       99.64
# RATE_INTEREST_PRIMARY          99.64
# RATE_DOWN_PAYMENT              53.64
# AMT_DOWN_PAYMENT               53.64
# NAME_TYPE_SUITE                49.12
# NFLAG_INSURED_ON_APPROVAL      40.30
# DAYS_FIRST_DRAWING             40.30
# DAYS_FIRST_DUE                 40.30
# DAYS_LAST_DUE_1ST_VERSION      40.30
# DAYS_LAST_DUE                  40.30
# DAYS_TERMINATION               40.30
# AMT_GOODS_PRICE                23.08
# AMT_ANNUITY                    22.29
# CNT_PAYMENT                    22.29
# PRODUCT_COMBINATION             0.02
# CHANNEL_TYPE                    0.00
# NAME_PRODUCT_TYPE               0.00
# NAME_YIELD_GROUP                0.00
# SELLERPLACE_AREA                0.00
# NAME_SELLER_INDUSTRY            0.00
# NAME_GOODS_CATEGORY             0.00
# NAME_PORTFOLIO                  0.00
# SK_ID_PREV                      0.00
# NAME_CLIENT_TYPE                0.00
# CODE_REJECT_REASON              0.00
# ...

# %% [markdown]
# # In this, previous dataframe imported and listed columns according to %Null values in descending order.

# %%
filtered_dataframe2 = pd.concat([filtered_dataframe1, df2['SK_ID_CURR']], axis=1)

# %%
filtered_dataframe2.columns
# Out:
# Index(['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'AGE', 'YEARS_OF_EXP', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT_W_CITY', 'ORGANIZATION_TYPE',
#        'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE',
#        'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'SK_ID_CURR'],
#       dtype='object')

# %%
prev_df = df1[['SK_ID_PREV',
'SK_ID_CURR',
'NAME_CONTRACT_TYPE',
'AMT_ANNUITY',
'AMT_APPLICATION',
'AMT_CREDIT',
'AMT_GOODS_PRICE',
'NAME_CASH_LOAN_PURPOSE',
'NAME_CONTRACT_STATUS',
'CODE_REJECT_REASON',
'NAME_CLIENT_TYPE']]

# %% [markdown]
# # selection of necessary columns according to own understanding from previous datasheet

# %%
filtered_dataframe2 = pd.merge(left = filtered_dataframe2, right=prev_df, on='SK_ID_CURR',how='inner')

# %%
filtered_dataframe2.shape
# Out:
# (1413701, 43)

# %%
sns.countplot(x="AGE", hue="NAME_CONTRACT_STATUS", data=filtered_dataframe2)
# Out:
# <Axes: xlabel='AGE', ylabel='count'>

# %% [markdown]
# # From above graph it can be observed that ,
#
# 1) Loan mostly get approved for the age band of 31 to 40
# 2) The second highest age band where loan gets approved is 41-50

# %%
sns.countplot(x="NAME_FAMILY_STATUS", hue="NAME_CONTRACT_STATUS", data=filtered_dataframe2)
# Out:
# <Axes: xlabel='NAME_FAMILY_STATUS', ylabel='count'>

# %% [markdown]
# # From the above graph it can be observed that,
#
# 1) The loan gets approved mostly for married people

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="NAME_EDUCATION_TYPE", hue="NAME_CONTRACT_STATUS", data=filtered_dataframe2)
# Out:
# <Axes: xlabel='NAME_EDUCATION_TYPE', ylabel='count'>

# %% [markdown]
# # For above graph it can be observed that,
#
# 1) The people who are educated till secondary / secondary-special have the highest count of getting the loan approved

# %%
sns.countplot(x="NAME_CLIENT_TYPE", hue="NAME_CONTRACT_STATUS", data=filtered_dataframe2)
# Out:
# <Axes: xlabel='NAME_CLIENT_TYPE', ylabel='count'>

# %% [markdown]
# # From the above graph , it can be observed that,
#
# 1) Maximum applications which are approved are of the applications which are refreshed Which means the people who are applying for the loan maybe second/third time , their applications get approved faster.

# %% [markdown]
# # Conclusion:
#
# Client categories to be targeted for providing loan
#
# 1) Clients in the age range 30-40 and 40-50
# 2) Clients who are Married
# 3) Clients who have education secondary/secondary special
# 4) Repeater clients
# 5) Clients who are male
# 6) Clients that are either students or businessman

# %%
categorical_columns = filtered_dataframe2.select_dtypes(include='object')

# %%
categorical_columns.columns
# Out:
# Index(['NAME_CONTRACT_TYPE_x', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'OCCUPATION_TYPE', 'ORGANIZATION_TYPE', 'NAME_CONTRACT_TYPE_y',
#        'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'CODE_REJECT_REASON',
#        'NAME_CLIENT_TYPE'],
#       dtype='object')

# %%
categorical_columns = categorical_columns.drop(columns = ['NAME_CONTRACT_STATUS'])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
l1 = categorical_columns.columns

# %%
for i in range(len(l1)):
    categorical_columns[l1[i]] = le.fit_transform(categorical_columns[l1[i]])

# %%
filtered_dataframe2 = filtered_dataframe2.drop(columns=['NAME_CONTRACT_TYPE_x', 'CODE_GENDER', 'FLAG_OWN_CAR',
       'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
       'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
       'OCCUPATION_TYPE', 'ORGANIZATION_TYPE', 'NAME_CONTRACT_TYPE_y',
       'NAME_CASH_LOAN_PURPOSE', 'CODE_REJECT_REASON', 'NAME_CLIENT_TYPE'])

# %%
filtered_dataframe2 = pd.concat([filtered_dataframe2,categorical_columns],axis = 1)

# %%
filtered_dataframe2 = filtered_dataframe2.dropna(axis = 0,how='any')

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(filtered_dataframe2.drop(columns=['NAME_CONTRACT_STATUS','AGE','YEARS_OF_EXP'],axis = 1)
                                                 ,filtered_dataframe2['NAME_CONTRACT_STATUS'],test_size = 0.25)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score

# %%
mod = LogisticRegression().fit(x_train, y_train)
# Out:
# c:\Users\vaibhau\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred = mod.predict(x_test)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8054656126556299

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
# c:\Users\vaibhau\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\vaibhau\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#     Approved       0.82      0.98      0.89    170235
#     Canceled       0.11      0.00      0.00      1825
#      Refused       0.57      0.13      0.21     41158
# Unused offer       0.00      0.00      0.00       189
#
# ...

# %%
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[166493,      6,   3736,      0],
#        [  1431,      4,    390,      0],
#        [ 35735,     28,   5395,      0],
#        [   189,      0,      0,      0]], dtype=int64)

# %% [markdown]
# # In this We have done all the necessary steps to make the model:
# 1) merging of two dataframes filtered_dataframe2 and prev_df
# 2) We have imported categorical columns into the variable categorical_columns
# 3) then dropped the response column from the list
# 4) Further we have converted categorical columns to numerical using encoder.
# 5) We dropped the main categorical columns from main dataframe
# 6) We append the dummy columns
# 7) Formulation of model

# %% [markdown]
# # Result
# 1) We have achievd 80% Accuracy by using Logistic Regression Model.
# 2) Model has given 82% Precision for Approved loans and highest after that 55% for Refused Loan offer.
# 3) Recall value is highest for approved loan offer with 98%
